# %% [markdown]
# # Long hanging fruit from challenges

# %% [markdown]
# - Python automatically handles long vs int. We never write long(), python automatically upgrades it behind the scenes
